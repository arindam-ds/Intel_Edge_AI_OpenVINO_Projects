# %% [markdown]
# # Smart Queue Monitoring System - Manufacturing Scenario
#
# ## Overview
# Now that you have your Python script and job submission script, you're ready to request an **IEI Tank-870** edge node and run inference on the different hardware types (CPU, GPU, VPU, FPGA).
#
# After the inference is completed, the output video and stats files need to be retrieved and stored in the workspace, which can then be viewed within the Jupyter Notebook.
#
# ## Objectives
# * Submit inference jobs to Intel's DevCloud using the `qsub` command.
# * Retrieve and review the results.
# * After testing, go back to the proposal doc and update your original proposed hardware device.

# %% [markdown]
# ## Step 0: Set Up
#
# #### IMPORTANT: Set up paths so we can run Dev Cloud utilities
# You *must* run this every time you enter a Workspace session.
# (Tip: select the cell and use **Shift+Enter** to run the cell.)

# %%
# %env PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support
import os
import sys
sys.path.insert(0, os.path.abspath('/opt/intel_devcloud_support'))
sys.path.insert(0, os.path.abspath('/opt/intel'))
# Out:
# env: PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support

# %% [markdown]
# ### Step 0.1:  (Optional-step): Original Video
#
# If you are curious to see the input video, run the following cell to view the original video stream we'll be using for inference.

# %%
import videoHtml
videoHtml.videoHTML('Manufacturing', ['original_videos/Manufacturing.mp4'])
# Out:
# <h5>Manufacturing</h5>
#         <video alt="" controls autoplay muted height="480"><source src="original_videos/Manufacturing.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1 : Inference on a Video
#
# In the next few cells, You'll submit your job using the `qsub` command and retrieve the results for each job. Each of the cells below should submit a job to different edge compute nodes.
#
# The output of the cell is the `JobID` of your job, which you can use to track progress of a job with `liveQStat`.
#
# You will need to submit a job for each of the following hardware types:
# * **CPU**
# * **GPU**
# * **VPU**
# * **FPGA**
#
# **Note:** You will have to submit each job one at a time and retrieve their results.
#
# After submission, they will go into a queue and run as soon as the requested compute resources become available.
# (Tip: **shift+enter** will run the cell and automatically move you to the next cell.)
#
# If your job successfully runs and completes, once you retrieve your results, it should output a video and a stats text file in the `results/manufacturing/<DEVICE>` directory.
#
# For example, your **CPU** job should output its files in this directory:
# > **results/manufacturing/cpu**
#
# **Note**: To get the queue labels for the different hardware devices, you can go to [this link](https://devcloud.intel.com/edge/get_started/devcloud/).
#
# The following arguments should be passed to the job submission script after the `-F` flag:
# * Model path - `/data/models/intel/person-detection-retail-0013/<MODEL PRECISION>/`. You will need to adjust this path based on the model precision being using on the hardware.
# * Device - `CPU`, `GPU`, `MYRIAD`, `HETERO:FPGA,CPU`.
# * Manufacturing video path - `/data/resources/manufacturing.mp4`.
# * Manufacturing queue_param file path - `/data/queue_param/manufacturing.npy`.
# * Output path - `/output/results/manufacturing/<DEVICE>` This should be adjusted based on the device used in the job.
# * Max num of people - This is the max number of people in queue before the system would redirect them to another queue.

# %% [markdown]
# ## Step 1.1: Submit to an Edge Compute Node with an Intel CPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a
#     href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500TE processor</a>. The inference workload should run on the CPU.

# %%
#Submit job to the queue
cpu_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 CPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/cpu 2" -N store_core

print(cpu_job_id[0])
# Out:
# 5jKMu0FGg58SwSPgdWY1HOcnhPA4m8T3

# %% [markdown]
# #### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(cpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:5jKMu0FGg58SwSPgdWY1HOcnhPA4m8T3) are ready.
# Please wait............................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# coords: [array([0.        , 1.        , 0.9986187 , 0.30903625, 0.24537906,
#        0.4528287 , 0.86759675], dtype=float32), array([0.        , 1.        , 0.99787056, 0.5067713 , 0.21938261,
#        0.6665517 , 0.82128906], dtype=float32), array([0.        , 1.        , 0.9974917 , 0.05004625, 0.25952595,
#        0.22120734, 0.9733233 ], dtype=float32), array([0.        , 1.        , 0.9948237 , 0.6674137 , 0.24150956,
#        0.7772058 , 0.7710006 ], dtype=float32), array([0.        , 1.        , 0.9583675 , 0.7991491 , 0.2505054 ,
#        0.9235446 , 0.69021326], dtype=float32), array([0.        , 1.        , 0.8672094 , 0.7440067 , 0.227281  ,
#        0.80798894, 0.59132254], dtype=float32), array([0.        , 1.        , 0.8144153 , 0.9240947 , 0.24980518,
#        0.9946079 , 0.56206393], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9985588 , 0.3088771 , 0.24517244,
#        0.4530545 , 0.8709217 ], dtype=float32), array([0.        , 1.        , 0.99769896, 0.04962135, 0.26144773,
#        0.22148982, 0.97354084], dtype=float32), array([0.        , 1.        , 0.99767417, 0.50445074, 0.21646634,
#        0.6658407 , 0.82395315], dtype=float32), array([0.        , 1.        , 0.9947365 , 0.66740435, 0.24072868,
#        0.77789336, 0.77085584], dtype=float32), array([0.        , 1.        , 0.95054567, 0.795363  , 0.25189865,
#        0.9223444 , 0.69149303], dtype=float32), array([0.        , 1.        , 0.8792871 , 0.744407  , 0.22567429,
#        0.8091654 , 0.59060955], dtype=float32), array([0.        , 1.        , 0.78565496, 0.9254618 , 0.24990256,
#        0.99514   , 0.5615552 ], dtype=float32), array([0.        , 1.        , 0.6193995 , 0.90113056, 0.25311643,
#        0.9568676 , 0.52862525], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99858886, 0.30904436, 0.24460316,
#        0.45310193, 0.8705256 ], dtype=float32), array([0.        , 1.        , 0.99773574, 0.04995671, 0.26292703,
#        0.22142464, 0.9728519 ], dtype=float32), array([0.        , 1.        , 0.99645126, 0.50321966, 0.21709874,
#        0.6668542 , 0.8230854 ], dtype=float32), array([0.        , 1.        , 0.9947555 , 0.66670436, 0.23965287,
#        0.7781394 , 0.7705896 ], dtype=float32), array([0.        , 1.        , 0.94584763, 0.7948944 , 0.25234038,
#        0.9227255 , 0.6889539 ], dtype=float32), array([0.        , 1.        , 0.9113329 , 0.7436103 , 0.22798665,
#        0.8086528 , 0.59071594], dtype=float32), array([0.        , 1.        , 0.8235862 , 0.92652965, 0.24945691,
#        0.9961072 , 0.5629686 ], dtype=float32), array([0.        , 1.        , 0.6564863 , 0.9010041 , 0.25204813,
#        0.95693743, 0.52867466], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99850357, 0.30931202, 0.24496901,
#        0.4524307 , 0.8724216 ], dtype=float32), array([0.        , 1.        , 0.9977591 , 0.04985014, 0.26186508,
#        0.22136143, 0.9730666 ], dtype=float32), array([0.        , 1.        , 0.9956899 , 0.5054801 , 0.21520144,
#        0.6703742 , 0.8187807 ], dtype=float32), array([0.        , 1.        , 0.99457484, 0.66666335, 0.23762292,
#        0.77945536, 0.77203566], dtype=float32), array([0.        , 1.        , 0.9487652 , 0.74671775, 0.22179788,
#        0.80835027, 0.5865215 ], dtype=float32), array([0.        , 1.        , 0.94610107, 0.79288256, 0.25206524,
#        0.9226819 , 0.690788  ], dtype=float32), array([0.        , 1.        , 0.8528343 , 0.927714  , 0.24711666,
#        0.9966135 , 0.56384337], dtype=float32), array([0.        , 1.        , 0.6936471 , 0.90090287, 0.2509513 ,
#        0.95661163, 0.5283882 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99843735, 0.30874032, 0.24465677,
#        0.4524758 , 0.87845004], dtype=float32), array([0.        , 1.        , 0.99775946, 0.04943554, 0.26163054,
#        0.22147854, 0.9710976 ], dtype=float32), array([0.        , 1.        , 0.99571687, 0.5056024 , 0.21582738,
#        0.67082447, 0.81773543], dtype=float32), array([0.        , 1.        , 0.99447256, 0.6657601 , 0.23687926,
#        0.7796417 , 0.77221763], dtype=float32), array([0.        , 1.        , 0.96186197, 0.7472641 , 0.22137891,
#        0.80816704, 0.5858097 ], dtype=float32), array([0.        , 1.        , 0.9446102 , 0.7927227 , 0.25299126,
#        0.9224    , 0.6908697 ], dtype=float32), array([0.        , 1.        , 0.82959276, 0.9282618 , 0.24740693,
#        0.99677855, 0.56583774], dtype=float32), array([0.        , 1.        , 0.73749715, 0.90026903, 0.2493669 ,
#        0.95683837, 0.53037596], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9986695 , 0.30827862, 0.24478939,
#        0.45171225, 0.8747823 ], dtype=float32), array([0.        , 1.        , 0.9975344 , 0.04878761, 0.26158494,
#        0.22155829, 0.97625524], dtype=float32), array([0.        , 1.        , 0.9962275 , 0.5089712 , 0.21632591,
#        0.672706  , 0.8133085 ], dtype=float32), array([0.        , 1.        , 0.993952  , 0.6653245 , 0.23680127,
#        0.78036076, 0.771744  ], dtype=float32), array([0.        , 1.        , 0.9622733 , 0.7471974 , 0.22119793,
#        0.8083714 , 0.58623004], dtype=float32), array([0.        , 1.        , 0.9606432 , 0.795277  , 0.2523995 ,
#        0.92182446, 0.69226277], dtype=float32), array([0.        , 1.        , 0.85285455, 0.92769957, 0.24666888,
#        0.9965476 , 0.5636048 ], dtype=float32), array([0.        , 1.        , 0.72199535, 0.900737  , 0.25015748,
#        0.95728713, 0.52902263], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9986772 , 0.30825058, 0.24595457,
#        0.45291367, 0.87173766], dtype=float32), array([0.        , 1.        , 0.9975726 , 0.04867803, 0.2620955 ,
#        0.22158192, 0.9779547 ], dtype=float32), array([0.        , 1.        , 0.9958118 , 0.5038709 , 0.21554002,
#        0.67218894, 0.8126348 ], dtype=float32), array([0.        , 1.        , 0.9932555 , 0.6660242 , 0.23721346,
#        0.7820926 , 0.7737212 ], dtype=float32), array([0.        , 1.        , 0.96244425, 0.79346496, 0.2520032 ,
#        0.9211113 , 0.6921442 ], dtype=float32), array([0.        , 1.        , 0.94716316, 0.746667  , 0.22170979,
#        0.80806637, 0.58529776], dtype=float32), array([0.        , 1.        , 0.83419615, 0.9276134 , 0.24840176,
#        0.99660933, 0.5636456 ], dtype=float32), array([0.        , 1.        , 0.7147666 , 0.90071464, 0.25047314,
#        0.9568111 , 0.5279907 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99853635, 0.30824548, 0.2472052 ,
#        0.45355773, 0.8737976 ], dtype=float32), array([0.        , 1.        , 0.9976191 , 0.04879069, 0.26183492,
#        0.2214905 , 0.97589606], dtype=float32), array([0.        , 1.        , 0.9959453 , 0.50701916, 0.21659166,
#        0.6715354 , 0.8117365 ], dtype=float32), array([0.        , 1.        , 0.99413437, 0.6659516 , 0.2370314 ,
#        0.78172874, 0.7742477 ], dtype=float32), array([0.        , 1.        , 0.9700726 , 0.795528  , 0.25053012,
#        0.9206818 , 0.69295263], dtype=float32), array([0.        , 1.        , 0.9467163 , 0.74674004, 0.22281918,
#        0.80763584, 0.5867871 ], dtype=float32), array([0.        , 1.        , 0.8561926 , 0.92744476, 0.24773462,
#        0.99671894, 0.563138  ], dtype=float32), array([0.        , 1.        , 0.7212022 , 0.9007441 , 0.2506155 ,
#        0.9570445 , 0.52871966], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9986141 , 0.30815494, 0.24734026,
#        0.45357662, 0.8740038 ], dtype=float32), array([0.        , 1.        , 0.9975562 , 0.04849803, 0.26180172,
#        0.22144449, 0.97975016], dtype=float32), array([0.        , 1.        , 0.9963464 , 0.5078717 , 0.21562842,
#        0.669872  , 0.8115963 ], dtype=float32), array([0.        , 1.        , 0.9946911 , 0.6663976 , 0.23675522,
#        0.7807274 , 0.7743802 ], dtype=float32), array([0.        , 1.        , 0.9759375 , 0.7993301 , 0.25218895,
#        0.9203937 , 0.69155836], dtype=float32), array([0.        , 1.        , 0.9474679 , 0.7475322 , 0.22494389,
#        0.8076561 , 0.59357905], dtype=float32), array([0.        , 1.        , 0.8508132 , 0.92838883, 0.24696139,
#        0.9973836 , 0.56112456], dtype=float32), array([0.        , 1.        , 0.7390165 , 0.8995681 , 0.25014505,
#        0.958061  , 0.530766  ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99839216, 0.3086336 , 0.24685264,
#        0.45231357, 0.8749459 ], dtype=float32), array([0.        , 1.        , 0.99737406, 0.04908206, 0.26248223,
#        0.22153278, 0.98090047], dtype=float32), array([0.        , 1.        , 0.99616736, 0.5030705 , 0.21574938,
#        0.6695951 , 0.81233466], dtype=float32), array([0.        , 1.        , 0.9945695 , 0.6667276 , 0.23733425,
#        0.7811876 , 0.7746302 ], dtype=float32), array([0.        , 1.        , 0.9785891 , 0.79950416, 0.2514512 ,
#        0.9204321 , 0.69394815], dtype=float32), array([0.        , 1.        , 0.93145376, 0.74755627, 0.23469771,
#        0.80743366, 0.589964  ], dtype=float32), array([0.        , 1.        , 0.87736833, 0.9290966 , 0.24511334,
#        0.9981693 , 0.5599786 ], dtype=float32), array([0.        , 1.        , 0.73643774, 0.8992565 , 0.25185907,
#        0.95807856, 0.5306776 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99833846, 0.30788457, 0.24509802,
#        0.4538657 , 0.87443733], dtype=float32), array([0.        , 1.        , 0.9973955 , 0.0493305 , 0.2636442 ,
#        0.22134295, 0.9815234 ], dtype=float32), array([0.        , 1.        , 0.9965475 , 0.5046682 , 0.21536976,
#        0.6694438 , 0.81258506], dtype=float32), array([0.        , 1.        , 0.99434423, 0.6658636 , 0.236837  ,
#        0.78035027, 0.77418494], dtype=float32), array([0.        , 1.        , 0.97920954, 0.79987866, 0.25173044,
#        0.9201934 , 0.6959974 ], dtype=float32), array([0.        , 1.        , 0.89002377, 0.9295993 , 0.2432159 ,
#        0.9985031 , 0.5594814 ], dtype=float32), array([0.        , 1.        , 0.8775529 , 0.74825275, 0.23936293,
#        0.8062203 , 0.5872929 ], dtype=float32), array([0.        , 1.        , 0.7348961 , 0.8985299 , 0.25215322,
#        0.9571661 , 0.5300157 ], dtype=float32), array([0.        , 1.        , 0.6020899 , 0.6294363 , 0.23842494,
#        0.64356023, 0.29345432], dtype=float32)]
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.998387  , 0.30814487, 0.24350506,
#        0.45324582, 0.8764127 ], dtype=float32), array([0.        , 1.        , 0.9972459 , 0.04900516, 0.26373503,
#        0.22141919, 0.9821727 ], dtype=float32), array([0.        , 1.        , 0.9964018 , 0.501202  , 0.21687391,
#        0.6691692 , 0.8134041 ], dtype=float32), array([0.        , 1.        , 0.9941426 , 0.66653776, 0.2359739 ,
#        0.7808775 , 0.7752189 ], dtype=float32), array([0.        , 1.        , 0.9796596 , 0.8008437 , 0.25282025,
#        0.9200158 , 0.69642836], dtype=float32), array([0.        , 1.        , 0.90662104, 0.92977667, 0.24218659,
#        0.9989023 , 0.5587803 ], dtype=float32), array([0.        , 1.        , 0.85319   , 0.74838585, 0.24256244,
#        0.8068693 , 0.58678365], dtype=float32), array([0.        , 1.        , 0.72688675, 0.8966398 , 0.2509986 ,
#        0.95615757, 0.53095245], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99824834, 0.30896425, 0.24236664,
#        0.45276666, 0.8814765 ], dtype=float32), array([0.        , 1.        , 0.9972356 , 0.04941922, 0.26436132,
#        0.22148788, 0.9807387 ], dtype=float32), array([0.        , 1.        , 0.9961992 , 0.50114405, 0.21718377,
#        0.6680542 , 0.8109656 ], dtype=float32), array([0.        , 1.        , 0.99375075, 0.66597515, 0.23562717,
#        0.7810231 , 0.77623355], dtype=float32), array([0.        , 1.        , 0.97681695, 0.8009953 , 0.25155884,
#        0.92001504, 0.6935466 ], dtype=float32), array([0.        , 1.        , 0.90733707, 0.93119526, 0.24002512,
#        0.9995688 , 0.5589066 ], dtype=float32), array([0.        , 1.        , 0.7793271 , 0.74872816, 0.24502043,
#        0.8067018 , 0.5856293 ], dtype=float32), array([0.        , 1.        , 0.7503966 , 0.89520645, 0.2510656 ,
#        0.95486164, 0.53079635], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9978009 , 0.3109326 , 0.23931515,
#        0.45062128, 0.88313997], dtype=float32), array([0.        , 1.        , 0.9972395 , 0.04976284, 0.2635558 ,
#        0.22109395, 0.97791684], dtype=float32), array([0.        , 1.        , 0.9964766 , 0.5024694 , 0.21599603,
#        0.6690006 , 0.81045794], dtype=float32), array([0.        , 1.        , 0.99334186, 0.6658951 , 0.24089065,
#        0.7812568 , 0.77277803], dtype=float32), array([0.        , 1.        , 0.9688047 , 0.8016989 , 0.25524506,
#        0.92272174, 0.6900426 ], dtype=float32), array([0.        , 1.        , 0.8948539 , 0.9315174 , 0.24070671,
#        0.99925154, 0.5597373 ], dtype=float32), array([0.        , 1.        , 0.76621836, 0.89548635, 0.25221178,
#        0.95519114, 0.5328407 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9975037 , 0.3127518 , 0.23964432,
#        0.44849488, 0.8821616 ], dtype=float32), array([0.        , 1.        , 0.99726164, 0.05018689, 0.26370123,
#        0.22096351, 0.97734785], dtype=float32), array([0.        , 1.        , 0.99684215, 0.4988988 , 0.21763363,
#        0.6680549 , 0.81044436], dtype=float32), array([0.        , 1.        , 0.9933781 , 0.6645764 , 0.23606426,
#        0.78096604, 0.77678984], dtype=float32), array([0.        , 1.        , 0.9682386 , 0.8019696 , 0.2545093 ,
#        0.92206734, 0.6880444 ], dtype=float32), array([0.        , 1.        , 0.8791213 , 0.93159944, 0.24103977,
#        0.998938  , 0.5598737 ], dtype=float32), array([0.        , 1.        , 0.72541815, 0.8962481 , 0.2537954 ,
#        0.9548321 , 0.53293467], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9973429 , 0.31610933, 0.25334004,
#        0.4480115 , 0.88281775], dtype=float32), array([0.        , 1.        , 0.99721485, 0.05010318, 0.2644395 ,
#        0.22106534, 0.9779688 ], dtype=float32), array([0.        , 1.        , 0.9969988 , 0.49811226, 0.21792203,
#        0.6668231 , 0.81143004], dtype=float32), array([0.        , 1.        , 0.9927452 , 0.6652113 , 0.23654675,
#        0.78111386, 0.77518034], dtype=float32), array([0.        , 1.        , 0.96854186, 0.801094  , 0.25458997,
#        0.92166406, 0.6898883 ], dtype=float32), array([0.        , 1.        , 0.90362865, 0.93136036, 0.2393681 ,
#        0.9990226 , 0.5593844 ], dtype=float32), array([0.        , 1.        , 0.7118664 , 0.8983051 , 0.25410348,
#        0.95367104, 0.52826095], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9976835 , 0.4991455 , 0.21727523,
#        0.6641998 , 0.8160937 ], dtype=float32), array([0.        , 1.        , 0.99754804, 0.31684077, 0.25265142,
#        0.4475633 , 0.8855386 ], dtype=float32), array([0.        , 1.        , 0.9974753 , 0.04993228, 0.2639672 ,
#        0.22090542, 0.9729352 ], dtype=float32), array([0.        , 1.        , 0.99276406, 0.66503537, 0.23717165,
#        0.78148913, 0.7756138 ], dtype=float32), array([0.        , 1.        , 0.9668705 , 0.799895  , 0.25534487,
#        0.9220862 , 0.6881279 ], dtype=float32), array([0.       , 1.       , 0.9083227, 0.930721 , 0.2395116, 0.9989714,
#        0.5593367], dtype=float32), array([0.        , 1.        , 0.72336924, 0.8973834 , 0.25328708,
#        0.95576996, 0.53065604], dtype=float32), array([0.        , 1.        , 0.61780304, 0.6296735 , 0.23858562,
#        0.6436248 , 0.2933065 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.9975466 , 0.50221497, 0.21406993,
#        0.66382104, 0.8188288 ], dtype=float32), array([0.        , 1.        , 0.9975108 , 0.31790787, 0.25325263,
#        0.44733638, 0.88199973], dtype=float32), array([0.        , 1.        , 0.99718106, 0.04974961, 0.2636521 ,
#        0.22127986, 0.97638345], dtype=float32), array([0.        , 1.        , 0.9926286 , 0.6644226 , 0.23688194,
#        0.7816672 , 0.77611566], dtype=float32), array([0.        , 1.        , 0.9689447 , 0.79849386, 0.25503796,
#        0.92149997, 0.6882139 ], dtype=float32), array([0.        , 1.        , 0.8174279 , 0.9303859 , 0.24246213,
#        0.99704415, 0.55991125], dtype=float32), array([0.        , 1.        , 0.78652716, 0.8990809 , 0.25155014,
#        0.95754087, 0.5324342 ], dtype=float32), array([0.        , 1.        , 0.60854036, 0.6292236 , 0.23925218,
#        0.64308333, 0.29260162], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.997781  , 0.50161266, 0.21529618,
#        0.66395414, 0.8200637 ], dtype=float32), array([0.        , 1.        , 0.99757546, 0.31707683, 0.25078997,
#        0.4473416 , 0.8812096 ], dtype=float32), array([0.        , 1.        , 0.99720997, 0.0498918 , 0.26451358,
#        0.22113106, 0.97762966], dtype=float32), array([0.        , 1.        , 0.9931377 , 0.66434366, 0.2375685 ,
#        0.78110164, 0.77670765], dtype=float32), array([0.        , 1.        , 0.9686377 , 0.79848844, 0.25480062,
#        0.9207458 , 0.69004035], dtype=float32), array([0.        , 1.        , 0.8303679 , 0.93024164, 0.24033019,
#        0.99710387, 0.558468  ], dtype=float32), array([0.        , 1.        , 0.72906065, 0.89922243, 0.2530957 ,
#        0.9569883 , 0.53076005], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9985752 , 0.49659532, 0.21632308,
#        0.6627678 , 0.81639785], dtype=float32), array([0.        , 1.        , 0.99773043, 0.31641155, 0.2519769 ,
#        0.4472986 , 0.8861638 ], dtype=float32), array([0.        , 1.        , 0.99725217, 0.04954118, 0.26463974,
#        0.22111416, 0.975726  ], dtype=float32), array([0.        , 1.        , 0.9928168 , 0.6658475 , 0.24150419,
#        0.78144974, 0.7726437 ], dtype=float32), array([0.        , 1.        , 0.96656626, 0.799581  , 0.25513476,
#        0.921616  , 0.6854477 ], dtype=float32), array([0.       , 1.       , 0.7918979, 0.931066 , 0.238981 , 0.9969483,
#        0.5582291], dtype=float32), array([0.        , 1.        , 0.77262753, 0.89843893, 0.24961244,
#        0.9566381 , 0.5327377 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99842215, 0.49948493, 0.21651366,
#        0.662338  , 0.81790984], dtype=float32), array([0.        , 1.        , 0.9977393 , 0.31665108, 0.25133893,
#        0.4473596 , 0.88653874], dtype=float32), array([0.        , 1.        , 0.9971322 , 0.04948512, 0.26446822,
#        0.22103795, 0.97693205], dtype=float32), array([0.        , 1.        , 0.99249107, 0.6656602 , 0.24064267,
#        0.78168935, 0.77278435], dtype=float32), array([0.        , 1.        , 0.9658902 , 0.79864043, 0.2554764 ,
#        0.9202011 , 0.68910277], dtype=float32), array([0.        , 1.        , 0.7868542 , 0.92983323, 0.23900163,
#        0.9958541 , 0.5607969 ], dtype=float32), array([0.        , 1.        , 0.7438266 , 0.89954734, 0.25006497,
#        0.95697284, 0.53164405], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9985538 , 0.50084424, 0.21669567,
#        0.661531  , 0.8182292 ], dtype=float32), array([0.        , 1.        , 0.9977241 , 0.31657395, 0.25159004,
#        0.44713446, 0.8828968 ], dtype=float32), array([0.        , 1.        , 0.99743855, 0.0491917 , 0.26415288,
#        0.22149141, 0.9732652 ], dtype=float32), array([0.        , 1.        , 0.9926709 , 0.66505694, 0.24078947,
#        0.7823229 , 0.7726874 ], dtype=float32), array([0.        , 1.        , 0.9687761 , 0.80008495, 0.25517568,
#        0.9213673 , 0.6871425 ], dtype=float32), array([0.        , 1.        , 0.74644023, 0.9301492 , 0.23824233,
#        0.99558604, 0.55952793], dtype=float32), array([0.        , 1.        , 0.7459536 , 0.89891183, 0.24927914,
#        0.9565568 , 0.533641  ], dtype=float32), array([0.        , 1.        , 0.6176622 , 0.6299604 , 0.23897064,
#        0.6437733 , 0.29214323], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.9985347 , 0.5060876 , 0.21569356,
#        0.66270155, 0.81706727], dtype=float32), array([0.        , 1.        , 0.9974705 , 0.31625703, 0.25259534,
#        0.44665542, 0.88513315], dtype=float32), array([0.        , 1.        , 0.9973907 , 0.04937531, 0.26361176,
#        0.22145574, 0.9736018 ], dtype=float32), array([0.        , 1.        , 0.9930662 , 0.66428626, 0.2369073 ,
#        0.78252566, 0.7735875 ], dtype=float32), array([0.        , 1.        , 0.96671563, 0.79929674, 0.25531363,
#        0.92072463, 0.6889651 ], dtype=float32), array([0.        , 1.        , 0.7516757 , 0.9001562 , 0.24900238,
#        0.9547458 , 0.5311092 ], dtype=float32), array([0.        , 1.        , 0.67707855, 0.9486648 , 0.2284959 ,
#        0.9987986 , 0.5619597 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9986292 , 0.50824094, 0.21685523,
#        0.6629963 , 0.8211201 ], dtype=float32), array([0.        , 1.        , 0.99770576, 0.3177094 , 0.25214124,
#        0.4459687 , 0.8808373 ], dtype=float32), array([0.        , 1.        , 0.99747926, 0.04928173, 0.26317793,
#        0.22138037, 0.9766912 ], dtype=float32), array([0.        , 1.        , 0.99269474, 0.66449606, 0.23745611,
#        0.7828847 , 0.7741637 ], dtype=float32), array([0.        , 1.        , 0.9669098 , 0.79898524, 0.2547558 ,
#        0.92225516, 0.6853345 ], dtype=float32), array([0.        , 1.        , 0.7521439 , 0.89999884, 0.25012523,
#        0.9548771 , 0.5304349 ], dtype=float32), array([0.        , 1.        , 0.6782096 , 0.92896223, 0.23961323,
#        0.9949155 , 0.55862355], dtype=float32), array([0.        , 1.        , 0.60903233, 0.62975115, 0.24000101,
#        0.64343697, 0.29315013], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.99829024, 0.50804543, 0.21713012,
#        0.6641959 , 0.8233095 ], dtype=float32), array([0.        , 1.        , 0.9975599 , 0.3182574 , 0.25339556,
#        0.44572598, 0.87971413], dtype=float32), array([0.        , 1.        , 0.9975389 , 0.04929991, 0.26204088,
#        0.22168933, 0.97516847], dtype=float32), array([0.        , 1.        , 0.9934615 , 0.6648194 , 0.23716402,
#        0.78340214, 0.7745757 ], dtype=float32), array([0.        , 1.        , 0.96816003, 0.79889214, 0.25507092,
#        0.9208771 , 0.68646485], dtype=float32), array([0.        , 1.        , 0.7488124 , 0.8992035 , 0.2503742 ,
#        0.95650274, 0.5343434 ], dtype=float32), array([0.        , 1.        , 0.6672924 , 0.94787055, 0.23285958,
#        0.99863964, 0.55870426], dtype=float32), array([0.        , 1.        , 0.6253086 , 0.6299227 , 0.2395807 ,
#        0.64365834, 0.29325807], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.99781966, 0.5134272 , 0.21862292,
#        0.667146  , 0.8209574 ], dtype=float32), array([0.        , 1.        , 0.99780124, 0.31980854, 0.25103277,
#        0.446051  , 0.88045686], dtype=float32), array([0.        , 1.        , 0.99726486, 0.0490742 , 0.26158002,
#        0.22113946, 0.9805727 ], dtype=float32), array([0.        , 1.        , 0.9926005 , 0.66430783, 0.23226973,
#        0.78422546, 0.7768353 ], dtype=float32), array([0.        , 1.        , 0.96904695, 0.7976635 , 0.25404888,
#        0.9213672 , 0.68379706], dtype=float32), array([0.        , 1.        , 0.83282197, 0.8990142 , 0.24796076,
#        0.9566813 , 0.53382885], dtype=float32), array([0.        , 1.        , 0.6826478 , 0.9293085 , 0.24245611,
#        0.9950865 , 0.559047  ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99778384, 0.31863976, 0.25225598,
#        0.44803607, 0.8794102 ], dtype=float32), array([0.        , 1.        , 0.99767834, 0.52299756, 0.22150904,
#        0.6677955 , 0.81779295], dtype=float32), array([0.        , 1.        , 0.9973099 , 0.0495296 , 0.2615602 ,
#        0.22089666, 0.97819805], dtype=float32), array([0.       , 1.       , 0.9921657, 0.6642045, 0.2321949, 0.7841389,
#        0.7770027], dtype=float32), array([0.        , 1.        , 0.9676769 , 0.79694444, 0.25429237,
#        0.9212695 , 0.68321025], dtype=float32), array([0.        , 1.        , 0.83832115, 0.8995805 , 0.24728636,
#        0.9545903 , 0.5299383 ], dtype=float32), array([0.        , 1.        , 0.71362954, 0.9465176 , 0.2298646 ,
#        0.9984778 , 0.55866855], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9980234 , 0.31692213, 0.2511629 ,
#        0.45231527, 0.8851756 ], dtype=float32), array([0.        , 1.        , 0.99757904, 0.52762103, 0.2202642 ,
#        0.66795933, 0.816869  ], dtype=float32), array([0.        , 1.        , 0.99714214, 0.04945101, 0.2608827 ,
#        0.22074835, 0.97786176], dtype=float32), array([0.        , 1.        , 0.99139154, 0.6639383 , 0.23686758,
#        0.78304374, 0.77330256], dtype=float32), array([0.        , 1.        , 0.969296  , 0.7973505 , 0.2539088 ,
#        0.92049754, 0.6817861 ], dtype=float32), array([0.        , 1.        , 0.81708664, 0.90056247, 0.24840967,
#        0.9549709 , 0.52987266], dtype=float32), array([0.        , 1.        , 0.7147193 , 0.9298675 , 0.24009098,
#        0.9954183 , 0.5599336 ], dtype=float32), array([0.        , 1.        , 0.60036755, 0.62919915, 0.23785187,
#        0.6437377 , 0.29598352], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.9987167 , 0.31813842, 0.24618211,
#        0.45807087, 0.8853835 ], dtype=float32), array([0.        , 1.        , 0.99723756, 0.04894981, 0.26130217,
#        0.22111353, 0.97973937], dtype=float32), array([0.        , 1.        , 0.997074  , 0.5301944 , 0.21863616,
#        0.6679269 , 0.8161559 ], dtype=float32), array([0.        , 1.        , 0.99184024, 0.66467863, 0.23278818,
#        0.78393966, 0.77638316], dtype=float32), array([0.        , 1.        , 0.9699754 , 0.7979611 , 0.25478286,
#        0.92071533, 0.6837298 ], dtype=float32), array([0.        , 1.        , 0.77875876, 0.9000251 , 0.24703974,
#        0.9549223 , 0.53108114], dtype=float32), array([0.        , 1.        , 0.69359404, 0.9291729 , 0.23856017,
#        0.9951916 , 0.56013453], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99834585, 0.31788313, 0.24247545,
#        0.46547186, 0.8950519 ], dtype=float32), array([0.        , 1.        , 0.9972556 , 0.04821334, 0.26301947,
#        0.22475994, 0.98105204], dtype=float32), array([0.        , 1.        , 0.99566877, 0.5317276 , 0.21891871,
#        0.6684801 , 0.81219864], dtype=float32), array([0.        , 1.        , 0.9926509 , 0.6653616 , 0.23244056,
#        0.7841446 , 0.77666676], dtype=float32), array([0.        , 1.        , 0.9702678 , 0.79833186, 0.2542253 ,
#        0.9210532 , 0.68409026], dtype=float32), array([0.        , 1.        , 0.80564755, 0.8990389 , 0.24599667,
#        0.95446944, 0.53298235], dtype=float32), array([0.        , 1.        , 0.6312069 , 0.74933213, 0.25015092,
#        0.8049975 , 0.5815593 ], dtype=float32), array([0.        , 1.        , 0.60426474, 0.6294274 , 0.237067  ,
#        0.64389724, 0.29528686], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# coords: [array([0.        , 1.        , 0.99818355, 0.31912735, 0.24098754,
#        0.46880022, 0.89108944], dtype=float32), array([0.        , 1.        , 0.99733716, 0.04917514, 0.26113933,
#        0.2211034 , 0.9753154 ], dtype=float32), array([0.        , 1.        , 0.9958845 , 0.53272766, 0.21859184,
#        0.66872364, 0.8112128 ], dtype=float32), array([0.        , 1.        , 0.99230075, 0.6643536 , 0.24011755,
#        0.7822075 , 0.7722862 ], dtype=float32), array([0.        , 1.        , 0.967789  , 0.79891515, 0.2556976 ,
#        0.92126584, 0.68220216], dtype=float32), array([0.        , 1.        , 0.7655236 , 0.8989156 , 0.24648559,
#        0.95428675, 0.53221905], dtype=float32), array([0.        , 1.        , 0.63055134, 0.7504122 , 0.2505061 ,
#        0.8064382 , 0.58356154], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99792093, 0.31895483, 0.24242544,
#        0.47162366, 0.88936114], dtype=float32), array([0.        , 1.        , 0.9973303 , 0.04861549, 0.26433328,
#        0.22495148, 0.9815111 ], dtype=float32), array([0.        , 1.        , 0.9966009 , 0.5304887 , 0.21840638,
#        0.66837597, 0.81029457], dtype=float32), array([0.       , 1.       , 0.9919029, 0.6645088, 0.2367984, 0.7822403,
#        0.7781553], dtype=float32), array([0.        , 1.        , 0.9712847 , 0.7995425 , 0.25518614,
#        0.9213055 , 0.6831874 ], dtype=float32), array([0.        , 1.        , 0.76673675, 0.75175416, 0.24577266,
#        0.8088366 , 0.587482  ], dtype=float32), array([0.        , 1.        , 0.73582935, 0.89994293, 0.24629393,
#        0.9560749 , 0.53205204], dtype=float32), array([0.        , 1.        , 0.6843864 , 0.9244273 , 0.2399722 ,
#        0.99162996, 0.5577333 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9977982 , 0.04804531, 0.26766455,
#        0.22570714, 0.98011243], dtype=float32), array([0.        , 1.        , 0.9974256 , 0.31751022, 0.24408734,
#        0.4752144 , 0.8888086 ], dtype=float32), array([0.        , 1.        , 0.99737585, 0.52786493, 0.2174513 ,
#        0.6682508 , 0.81290793], dtype=float32), array([0.        , 1.        , 0.9928087 , 0.66536176, 0.23949653,
#        0.7820648 , 0.7728098 ], dtype=float32), array([0.        , 1.        , 0.96973395, 0.7995162 , 0.2558717 ,
#        0.9215735 , 0.6825725 ], dtype=float32), array([0.        , 1.        , 0.6804089 , 0.8988047 , 0.24638838,
#        0.9548033 , 0.5312112 ], dtype=float32), array([0.        , 1.        , 0.6763243 , 0.9263    , 0.2399786 ,
#        0.99436074, 0.5576402 ], dtype=float32), array([0.        , 1.        , 0.660001  , 0.7500402 , 0.24879643,
#        0.8065133 , 0.5851575 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99808973, 0.04689308, 0.26898557,
#        0.22631629, 0.9802579 ], dtype=float32), array([0.        , 1.        , 0.9979615 , 0.3176502 , 0.24666357,
#        0.4719587 , 0.88937473], dtype=float32), array([0.        , 1.        , 0.99741095, 0.52918124, 0.21650729,
#        0.6681334 , 0.8105222 ], dtype=float32), array([0.        , 1.        , 0.9929792 , 0.66586876, 0.2391313 ,
#        0.78198206, 0.7734226 ], dtype=float32), array([0.        , 1.        , 0.9682018 , 0.7969624 , 0.25598776,
#        0.9223186 , 0.6819512 ], dtype=float32), array([0.        , 1.        , 0.7337157 , 0.92127097, 0.24973534,
#        0.9916601 , 0.55756724], dtype=float32), array([0.        , 1.        , 0.7148292 , 0.7501316 , 0.24850295,
#        0.80588055, 0.5844429 ], dtype=float32), array([0.        , 1.        , 0.7107134 , 0.89757746, 0.24584359,
#        0.9593149 , 0.53820854], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981325 , 0.5295915 , 0.2164545 ,
#        0.66988236, 0.8083259 ], dtype=float32), array([0.        , 1.        , 0.9980197 , 0.31645545, 0.24771857,
#        0.47220793, 0.8883549 ], dtype=float32), array([0.        , 1.        , 0.9979418 , 0.04739277, 0.26813713,
#        0.22644325, 0.980098  ], dtype=float32), array([0.        , 1.        , 0.9936606 , 0.66651726, 0.23987576,
#        0.78195584, 0.773451  ], dtype=float32), array([0.        , 1.        , 0.96394676, 0.7975754 , 0.25586045,
#        0.92249864, 0.68275464], dtype=float32), array([0.        , 1.        , 0.65707225, 0.89887774, 0.24913637,
#        0.96042645, 0.53946096], dtype=float32), array([0.        , 1.        , 0.6253422 , 0.7491205 , 0.24842249,
#        0.80618405, 0.58583075], dtype=float32), array([0.        , 1.        , 0.61355996, 0.917621  , 0.2532091 ,
#        0.98893404, 0.5564849 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.998548  , 0.31399   , 0.24648076,
#        0.46703106, 0.8928538 ], dtype=float32), array([0.        , 1.        , 0.99814796, 0.5282129 , 0.21587607,
#        0.67098475, 0.80899966], dtype=float32), array([0.        , 1.        , 0.9979411 , 0.04733804, 0.2681133 ,
#        0.2265195 , 0.9816016 ], dtype=float32), array([0.        , 1.        , 0.99360317, 0.66972256, 0.24037498,
#        0.7815881 , 0.772338  ], dtype=float32), array([0.        , 1.        , 0.9642692 , 0.79531574, 0.25571567,
#        0.9227184 , 0.68450314], dtype=float32), array([0.        , 1.        , 0.7148577 , 0.74839133, 0.24494848,
#        0.8058619 , 0.58531594], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9988512 , 0.31114113, 0.24792302,
#        0.46509016, 0.8894893 ], dtype=float32), array([0.        , 1.        , 0.99823076, 0.52607083, 0.2179156 ,
#        0.6701728 , 0.8077602 ], dtype=float32), array([0.        , 1.        , 0.9975897 , 0.04924095, 0.26736158,
#        0.22610533, 0.97915417], dtype=float32), array([0.        , 1.        , 0.9940339 , 0.66976327, 0.23829108,
#        0.7807389 , 0.7760431 ], dtype=float32), array([0.        , 1.        , 0.9639071 , 0.7967427 , 0.25691742,
#        0.92300487, 0.6842108 ], dtype=float32), array([0.        , 1.        , 0.6475647 , 0.9005392 , 0.2503928 ,
#        0.959552  , 0.53835064], dtype=float32), array([0.        , 1.        , 0.62442416, 0.92032534, 0.25690913,
#        0.9901534 , 0.5591172 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99840695, 0.52379256, 0.21804091,
#        0.6709171 , 0.8065852 ], dtype=float32), array([0.        , 1.        , 0.99828416, 0.30871338, 0.24612638,
#        0.46731526, 0.88915956], dtype=float32), array([0.        , 1.        , 0.9973877 , 0.04990399, 0.2666097 ,
#        0.22635686, 0.9784552 ], dtype=float32), array([0.        , 1.        , 0.99416214, 0.6700655 , 0.23818505,
#        0.7805035 , 0.7758411 ], dtype=float32), array([0.        , 1.        , 0.9661607 , 0.7955668 , 0.25642702,
#        0.9228884 , 0.6862768 ], dtype=float32), array([0.        , 1.        , 0.7257981 , 0.91983706, 0.257561  ,
#        0.9894206 , 0.55942905], dtype=float32), array([0.        , 1.        , 0.6814538 , 0.7486936 , 0.24585234,
#        0.80664337, 0.5836846 ], dtype=float32), array([0.        , 1.        , 0.63420576, 0.90034485, 0.24632436,
#        0.9624518 , 0.5400449 ], dtype=float32)]
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9986003 , 0.30781522, 0.24702162,
#        0.4655008 , 0.8871117 ], dtype=float32), array([0.        , 1.        , 0.9982141 , 0.52346826, 0.21767336,
#        0.66970503, 0.80535454], dtype=float32), array([0.        , 1.        , 0.9974921 , 0.05122069, 0.26566264,
#        0.22255078, 0.9697931 ], dtype=float32), array([0.        , 1.        , 0.99423677, 0.6673778 , 0.23938581,
#        0.78002656, 0.77452886], dtype=float32), array([0.        , 1.        , 0.96661   , 0.7972615 , 0.25692427,
#        0.9232143 , 0.68536276], dtype=float32), array([0.        , 1.        , 0.67394865, 0.91826856, 0.2535553 ,
#        0.9889338 , 0.5544362 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99845254, 0.52449673, 0.21814898,
#        0.6701315 , 0.8063159 ], dtype=float32), array([0.        , 1.        , 0.9980046 , 0.30787456, 0.24374533,
#        0.4679721 , 0.8875586 ], dtype=float32), array([0.        , 1.        , 0.9973798 , 0.05241994, 0.26417246,
#        0.22242215, 0.9724251 ], dtype=float32), array([0.        , 1.        , 0.9946666 , 0.66911095, 0.23808652,
#        0.7798417 , 0.77372485], dtype=float32), array([0.        , 1.        , 0.9667221 , 0.796245  , 0.25551295,
#        0.9229369 , 0.68375534], dtype=float32), array([0.        , 1.        , 0.69832516, 0.7482334 , 0.24381624,
#        0.8060052 , 0.5849773 ], dtype=float32), array([0.        , 1.        , 0.6038634 , 0.9009798 , 0.2485317 ,
#        0.96328014, 0.5401128 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981839 , 0.3085275 , 0.24359465,
#        0.4702644 , 0.8878387 ], dtype=float32), array([0.        , 1.        , 0.998164  , 0.5239821 , 0.21821266,
#        0.6693916 , 0.80553836], dtype=float32), array([0.        , 1.        , 0.9977289 , 0.0540057 , 0.26387677,
#        0.22235072, 0.9717604 ], dtype=float32), array([0.        , 1.        , 0.99496424, 0.6689439 , 0.23905519,
#        0.7784753 , 0.7728051 ], dtype=float32), array([0.        , 1.        , 0.96779466, 0.7977106 , 0.25500864,
#        0.9228459 , 0.6854932 ], dtype=float32), array([0.        , 1.        , 0.80925465, 0.90117997, 0.24645622,
#        0.9631842 , 0.54272765], dtype=float32), array([0.        , 1.        , 0.6673745 , 0.7471204 , 0.24359056,
#        0.80496323, 0.5855104 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9984029 , 0.52486086, 0.21843037,
#        0.67007816, 0.8056241 ], dtype=float32), array([0.        , 1.        , 0.998395  , 0.30898604, 0.24293602,
#        0.47138402, 0.88394403], dtype=float32), array([0.        , 1.        , 0.9981185 , 0.05501683, 0.2658534 ,
#        0.222506  , 0.97339773], dtype=float32), array([0.        , 1.        , 0.99575436, 0.6692272 , 0.23805612,
#        0.7780867 , 0.7736148 ], dtype=float32), array([0.        , 1.        , 0.9679152 , 0.79743075, 0.25436914,
#        0.92287827, 0.68236065], dtype=float32), array([0.        , 1.        , 0.8431556 , 0.90187544, 0.24700043,
#        0.9630591 , 0.54207695], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99850225, 0.30870363, 0.24655786,
#        0.4684516 , 0.8827857 ], dtype=float32), array([0.        , 1.        , 0.9982079 , 0.05663377, 0.2650292 ,
#        0.22224492, 0.972355  ], dtype=float32), array([0.        , 1.        , 0.998198  , 0.5226619 , 0.21979687,
#        0.6699219 , 0.8078693 ], dtype=float32), array([0.        , 1.        , 0.9955917 , 0.66912323, 0.2403884 ,
#        0.77819425, 0.77261615], dtype=float32), array([0.        , 1.        , 0.9669458 , 0.79750633, 0.2547757 ,
#        0.9232627 , 0.6834423 ], dtype=float32), array([0.        , 1.        , 0.7979389 , 0.9004261 , 0.24739294,
#        0.96082217, 0.5408346 ], dtype=float32), array([0.        , 1.        , 0.6130141 , 0.95598954, 0.2555107 ,
#        0.999821  , 0.5717836 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9983569 , 0.05737482, 0.26524362,
#        0.22115304, 0.9727249 ], dtype=float32), array([0.        , 1.        , 0.9982444 , 0.30970594, 0.24726877,
#        0.47109213, 0.88129926], dtype=float32), array([0.        , 1.        , 0.99818194, 0.5220243 , 0.21944454,
#        0.6690068 , 0.80707157], dtype=float32), array([0.        , 1.        , 0.9959124 , 0.6695056 , 0.23966369,
#        0.7781589 , 0.7710315 ], dtype=float32), array([0.        , 1.        , 0.9658171 , 0.79596895, 0.25598094,
#        0.9230811 , 0.68331265], dtype=float32), array([0.        , 1.        , 0.79753613, 0.8999123 , 0.24518992,
#        0.9601428 , 0.5389806 ], dtype=float32), array([0.        , 1.        , 0.6292878 , 0.9552275 , 0.25146598,
#        0.9996737 , 0.57167494], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99826705, 0.0575884 , 0.26592994,
#        0.22068712, 0.9710685 ], dtype=float32), array([0.        , 1.        , 0.9981938 , 0.30943698, 0.2470487 ,
#        0.46985823, 0.8817711 ], dtype=float32), array([0.        , 1.        , 0.99805486, 0.5218026 , 0.2193645 ,
#        0.6690306 , 0.80756116], dtype=float32), array([0.        , 1.        , 0.99627954, 0.6701004 , 0.24253654,
#        0.77709776, 0.76901054], dtype=float32), array([0.        , 1.        , 0.9618845 , 0.79631203, 0.25677025,
#        0.92273563, 0.68256533], dtype=float32), array([0.        , 1.        , 0.67149067, 0.9001395 , 0.24757476,
#        0.9586107 , 0.53629214], dtype=float32), array([0.        , 1.        , 0.6438937 , 0.9548918 , 0.24799678,
#        0.9995643 , 0.57116485], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9980579 , 0.05740476, 0.26791668,
#        0.22189197, 0.97034657], dtype=float32), array([0.        , 1.        , 0.9980161 , 0.5218146 , 0.21862638,
#        0.66835034, 0.80538523], dtype=float32), array([0.        , 1.        , 0.9978339 , 0.30941945, 0.24531835,
#        0.4708693 , 0.8782001 ], dtype=float32), array([0.        , 1.        , 0.99623907, 0.6700895 , 0.24070877,
#        0.7770531 , 0.77039593], dtype=float32), array([0.        , 1.        , 0.96091115, 0.79576206, 0.2568249 ,
#        0.922729  , 0.68217915], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99810296, 0.05751938, 0.26607323,
#        0.22144502, 0.9698508 ], dtype=float32), array([0.        , 1.        , 0.99791414, 0.30858934, 0.24511755,
#        0.46609873, 0.8798008 ], dtype=float32), array([0.        , 1.        , 0.9978016 , 0.52099395, 0.2183207 ,
#        0.6679698 , 0.8063692 ], dtype=float32), array([0.        , 1.        , 0.9963529 , 0.6687535 , 0.24032679,
#        0.7764107 , 0.7711446 ], dtype=float32), array([0.        , 1.        , 0.96102285, 0.7962508 , 0.25600523,
#        0.92195094, 0.6819398 ], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99809045, 0.05616434, 0.2656742 ,
#        0.22166948, 0.9691118 ], dtype=float32), array([0.        , 1.        , 0.9978551 , 0.30974227, 0.24581584,
#        0.4651624 , 0.8775933 ], dtype=float32), array([0.        , 1.        , 0.9978446 , 0.52058613, 0.2185919 ,
#        0.6683953 , 0.8065475 ], dtype=float32), array([0.        , 1.        , 0.99636817, 0.66879016, 0.24058565,
#        0.7761603 , 0.7705747 ], dtype=float32), array([0.        , 1.        , 0.96354187, 0.7955109 , 0.2557751 ,
#        0.9217428 , 0.681932  ], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9980057 , 0.05648004, 0.2662114 ,
#        0.22135228, 0.96596885], dtype=float32), array([0.        , 1.        , 0.9977156 , 0.5200712 , 0.21906161,
#        0.6679396 , 0.8057201 ], dtype=float32), array([0.        , 1.        , 0.9975725 , 0.3114878 , 0.2461457 ,
#        0.46449286, 0.8769506 ], dtype=float32), array([0.        , 1.        , 0.99616724, 0.66865337, 0.24016574,
#        0.77595544, 0.7712015 ], dtype=float32), array([0.        , 1.        , 0.96251833, 0.7968175 , 0.25669983,
#        0.92109436, 0.68100595], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9978644 , 0.521899  , 0.21899846,
#        0.6688111 , 0.8055302 ], dtype=float32), array([0.        , 1.        , 0.9977912 , 0.31126577, 0.24522707,
#        0.46332842, 0.87816   ], dtype=float32), array([0.        , 1.        , 0.9977367 , 0.05582111, 0.2663491 ,
#        0.22128746, 0.96516347], dtype=float32), array([0.        , 1.        , 0.99632686, 0.6689236 , 0.2408494 ,
#        0.77610075, 0.7704309 ], dtype=float32), array([0.        , 1.        , 0.96310455, 0.79571766, 0.2557002 ,
#        0.9212926 , 0.6815393 ], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9976909 , 0.5230144 , 0.21954241,
#        0.66994417, 0.80527794], dtype=float32), array([0.        , 1.        , 0.99757344, 0.30987346, 0.24497488,
#        0.46585393, 0.8787687 ], dtype=float32), array([0.        , 1.        , 0.9975268 , 0.05556352, 0.26661134,
#        0.22025968, 0.9640635 ], dtype=float32), array([0.        , 1.        , 0.9959115 , 0.66940427, 0.2414152 ,
#        0.7754524 , 0.7685109 ], dtype=float32), array([0.        , 1.        , 0.96155834, 0.7964803 , 0.25752968,
#        0.92081964, 0.6830152 ], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99794775, 0.31100863, 0.24687573,
#        0.46337163, 0.8761922 ], dtype=float32), array([0.        , 1.        , 0.99744415, 0.05501897, 0.26744908,
#        0.22112784, 0.965898  ], dtype=float32), array([0.       , 1.       , 0.9974316, 0.5259979, 0.2206262, 0.6690736,
#        0.8069973], dtype=float32), array([0.        , 1.        , 0.99593407, 0.6699127 , 0.24119917,
#        0.77550197, 0.76789   ], dtype=float32), array([0.        , 1.        , 0.9629003 , 0.79596704, 0.25771552,
#        0.9211896 , 0.6861165 ], dtype=float32), array([0.        , 1.        , 0.6006632 , 0.7474134 , 0.24735098,
#        0.8043765 , 0.5858783 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99809057, 0.3110966 , 0.24810398,
#        0.45979697, 0.87655056], dtype=float32), array([0.        , 1.        , 0.99762744, 0.5264508 , 0.22122192,
#        0.6690858 , 0.80614567], dtype=float32), array([0.        , 1.        , 0.99733317, 0.05372276, 0.26760092,
#        0.2210345 , 0.96267474], dtype=float32), array([0.        , 1.        , 0.9959786 , 0.6696737 , 0.24104398,
#        0.775776  , 0.7688475 ], dtype=float32), array([0.        , 1.        , 0.96253234, 0.7963469 , 0.25781834,
#        0.92084146, 0.6860523 ], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99807537, 0.31157917, 0.24813765,
#        0.4568959 , 0.87772197], dtype=float32), array([0.        , 1.        , 0.9978198 , 0.52860844, 0.22110903,
#        0.6686003 , 0.8072041 ], dtype=float32), array([0.        , 1.        , 0.9972609 , 0.05303775, 0.2680382 ,
#        0.22091405, 0.96178263], dtype=float32), array([0.        , 1.        , 0.9962108 , 0.6701601 , 0.24145561,
# ...
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99829584, 0.04633717, 0.26935124,
#        0.22783644, 0.9747659 ], dtype=float32), array([0.        , 1.        , 0.99771464, 0.31096858, 0.23478931,
#        0.4453113 , 0.88382083], dtype=float32), array([0.        , 1.        , 0.99539053, 0.6691618 , 0.23464239,
#        0.7770556 , 0.7710253 ], dtype=float32), array([0.        , 1.        , 0.99030066, 0.55041796, 0.19974396,
#        0.6733251 , 0.79930866], dtype=float32), array([0.        , 1.        , 0.9666745 , 0.7994139 , 0.2560138 ,
#        0.9223546 , 0.68051165], dtype=float32), array([0.        , 1.        , 0.668252  , 0.8995712 , 0.24639454,
#        0.9549507 , 0.52890503], dtype=float32), array([0.        , 1.        , 0.6013232 , 0.7406571 , 0.24556266,
#        0.80449843, 0.5932885 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99825853, 0.04606964, 0.27212575,
#        0.22784865, 0.97576344], dtype=float32), array([0.        , 1.        , 0.9977034 , 0.31081027, 0.23327625,
#        0.44359422, 0.88473606], dtype=float32), array([0.        , 1.        , 0.9946585 , 0.66814727, 0.23432228,
#        0.77754456, 0.7710624 ], dtype=float32), array([0.        , 1.        , 0.98924726, 0.5481913 , 0.19934651,
#        0.6733413 , 0.80032337], dtype=float32), array([0.        , 1.        , 0.96477413, 0.79841936, 0.25615105,
#        0.9221301 , 0.68001914], dtype=float32), array([0.        , 1.        , 0.6906478 , 0.89965606, 0.24550432,
#        0.95434535, 0.5290825 ], dtype=float32), array([0.        , 1.        , 0.6528034 , 0.73840606, 0.24475674,
#        0.8035995 , 0.59588003], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99834573, 0.04569962, 0.27205008,
#        0.22771257, 0.97571486], dtype=float32), array([0.        , 1.        , 0.99770606, 0.31075484, 0.23367992,
#        0.44329202, 0.88457704], dtype=float32), array([0.        , 1.        , 0.99422824, 0.6680295 , 0.23347926,
#        0.77740735, 0.77064204], dtype=float32), array([0.        , 1.        , 0.9894163 , 0.5485839 , 0.19868279,
#        0.6734448 , 0.8008697 ], dtype=float32), array([0.        , 1.        , 0.9655128 , 0.79860795, 0.25619853,
#        0.92231476, 0.6812727 ], dtype=float32), array([0.        , 1.        , 0.68801033, 0.89981425, 0.2476233 ,
#        0.9530159 , 0.5281832 ], dtype=float32), array([0.        , 1.        , 0.68421835, 0.74033886, 0.2464423 ,
#        0.805005  , 0.5987475 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99824727, 0.04596132, 0.2708514 ,
#        0.22732279, 0.97536135], dtype=float32), array([0.        , 1.        , 0.9978344 , 0.30977497, 0.23273215,
#        0.44418588, 0.8887129 ], dtype=float32), array([0.        , 1.        , 0.99397695, 0.6673132 , 0.23219675,
#        0.77854776, 0.7708487 ], dtype=float32), array([0.        , 1.        , 0.9894015 , 0.54822576, 0.19914457,
#        0.6734494 , 0.80055916], dtype=float32), array([0.        , 1.        , 0.96731734, 0.7981021 , 0.25485522,
#        0.9221576 , 0.68248636], dtype=float32), array([0.        , 1.        , 0.754503  , 0.7410699 , 0.24574196,
#        0.8056803 , 0.5997136 ], dtype=float32), array([0.        , 1.        , 0.67419076, 0.89938116, 0.24663784,
#        0.95431256, 0.53262913], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981001 , 0.04623866, 0.27086905,
#        0.22710791, 0.97628284], dtype=float32), array([0.        , 1.        , 0.99787855, 0.310417  , 0.2334339 ,
#        0.4453689 , 0.8905392 ], dtype=float32), array([0.        , 1.        , 0.9937412 , 0.66692   , 0.23261553,
#        0.77831846, 0.77113074], dtype=float32), array([0.        , 1.        , 0.98960334, 0.54657406, 0.19901732,
#        0.6731966 , 0.8012693 ], dtype=float32), array([0.        , 1.        , 0.9681616 , 0.79848266, 0.2553886 ,
#        0.92227936, 0.68158245], dtype=float32), array([0.        , 1.        , 0.7818194 , 0.7434985 , 0.24743766,
#        0.8074935 , 0.5981671 ], dtype=float32), array([0.        , 1.        , 0.6466847 , 0.8999131 , 0.24652496,
#        0.9535551 , 0.5308286 ], dtype=float32)]
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99811506, 0.30974954, 0.23360163,
#        0.44392264, 0.8913415 ], dtype=float32), array([0.        , 1.        , 0.99779725, 0.04707623, 0.27141762,
#        0.22668844, 0.9761056 ], dtype=float32), array([0.        , 1.        , 0.9934022 , 0.666465  , 0.23315495,
#        0.77880114, 0.7711943 ], dtype=float32), array([0.        , 1.        , 0.98949414, 0.54650295, 0.19873446,
#        0.6730609 , 0.79981625], dtype=float32), array([0.        , 1.        , 0.9671258 , 0.79969954, 0.2558992 ,
#        0.9225142 , 0.68084913], dtype=float32), array([0.        , 1.        , 0.7614426 , 0.7412568 , 0.24611343,
#        0.8051006 , 0.59718126], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.998262  , 0.30869073, 0.23474735,
#        0.44502532, 0.88775665], dtype=float32), array([0.        , 1.        , 0.9980096 , 0.04701596, 0.27176866,
#        0.22700623, 0.9769136 ], dtype=float32), array([0.        , 1.        , 0.9933832 , 0.66645426, 0.23311934,
#        0.7797045 , 0.7717197 ], dtype=float32), array([0.        , 1.        , 0.9916865 , 0.54418457, 0.20226324,
#        0.6729398 , 0.7993493 ], dtype=float32), array([0.        , 1.        , 0.9694984 , 0.7988246 , 0.25713435,
#        0.92226213, 0.6825391 ], dtype=float32), array([0.        , 1.        , 0.70483434, 0.74052626, 0.24904464,
#        0.80535144, 0.59641683], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981944 , 0.30873662, 0.23548871,
#        0.44674778, 0.8838596 ], dtype=float32), array([0.        , 1.        , 0.9981565 , 0.0468851 , 0.27158204,
#        0.22687757, 0.97797394], dtype=float32), array([0.        , 1.        , 0.9939029 , 0.66677266, 0.23457298,
#        0.7795935 , 0.77210987], dtype=float32), array([0.        , 1.        , 0.990096  , 0.54224944, 0.19870743,
#        0.6736841 , 0.79954135], dtype=float32), array([0.        , 1.        , 0.9660235 , 0.7978878 , 0.25775382,
#        0.92205596, 0.68269193], dtype=float32), array([0.        , 1.        , 0.7325617 , 0.7401384 , 0.2501474 ,
#        0.80384564, 0.5982757 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981857 , 0.04677533, 0.27128762,
#        0.22720106, 0.97882336], dtype=float32), array([0.        , 1.        , 0.99810034, 0.3094517 , 0.23513839,
#        0.44675118, 0.8826715 ], dtype=float32), array([0.        , 1.        , 0.99468875, 0.6677538 , 0.23511454,
#        0.7781522 , 0.7720194 ], dtype=float32), array([0.        , 1.        , 0.9890288 , 0.54416806, 0.19708642,
#        0.6738371 , 0.8017914 ], dtype=float32), array([0.        , 1.        , 0.96100676, 0.79732925, 0.25788832,
#        0.9225859 , 0.6836745 ], dtype=float32), array([0.        , 1.        , 0.656374  , 0.74367726, 0.25163636,
#        0.8028624 , 0.5914768 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99810374, 0.30911997, 0.23597664,
#        0.44860008, 0.8800673 ], dtype=float32), array([0.        , 1.        , 0.99809617, 0.04734713, 0.2713783 ,
#        0.22699693, 0.9788966 ], dtype=float32), array([0.        , 1.        , 0.9951814 , 0.66793716, 0.2345542 ,
#        0.7776625 , 0.7730876 ], dtype=float32), array([0.        , 1.        , 0.99131435, 0.5469483 , 0.20177898,
#        0.67396426, 0.8013401 ], dtype=float32), array([0.        , 1.        , 0.9643753 , 0.7976383 , 0.25753504,
#        0.9224919 , 0.68311864], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99821246, 0.3086668 , 0.23618391,
#        0.44892415, 0.8838556 ], dtype=float32), array([0.        , 1.        , 0.99804187, 0.04745355, 0.2706417 ,
#        0.22692585, 0.9784709 ], dtype=float32), array([0.        , 1.        , 0.9955966 , 0.6680647 , 0.23446187,
#        0.77846336, 0.7731309 ], dtype=float32), array([0.        , 1.        , 0.9917856 , 0.5430312 , 0.20333022,
#        0.67484736, 0.8011437 ], dtype=float32), array([0.        , 1.        , 0.9531041 , 0.79223967, 0.2553982 ,
#        0.9226223 , 0.68480116], dtype=float32)]
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981735 , 0.30891672, 0.236307  ,
#        0.44799945, 0.8833957 ], dtype=float32), array([0.        , 1.        , 0.99804354, 0.0477978 , 0.26919067,
#        0.22683224, 0.97719765], dtype=float32), array([0.        , 1.        , 0.99527776, 0.6670652 , 0.23486081,
#        0.77892655, 0.7738532 ], dtype=float32), array([0.        , 1.        , 0.9910061 , 0.53853965, 0.20483696,
#        0.6743065 , 0.8018068 ], dtype=float32), array([0.        , 1.        , 0.9526593 , 0.790017  , 0.2544877 ,
#        0.92267704, 0.6855898 ], dtype=float32), array([0.        , 1.        , 0.6059534 , 0.7419942 , 0.24653703,
#        0.8065137 , 0.5903006 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9980977 , 0.30893016, 0.23494056,
#        0.44933456, 0.8824401 ], dtype=float32), array([0.        , 1.        , 0.99782795, 0.04779416, 0.26830715,
#        0.22651333, 0.9782755 ], dtype=float32), array([0.        , 1.        , 0.9946413 , 0.66585064, 0.23635256,
#        0.7798606 , 0.7737111 ], dtype=float32), array([0.        , 1.        , 0.9903094 , 0.5375372 , 0.20460853,
#        0.6743016 , 0.80360985], dtype=float32), array([0.        , 1.        , 0.9528804 , 0.7896585 , 0.25538957,
#        0.9227516 , 0.68556046], dtype=float32), array([0.        , 1.        , 0.76634675, 0.74221283, 0.24684769,
#        0.80710715, 0.5910288 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981078 , 0.3094121 , 0.234577  ,
#        0.44894734, 0.8824845 ], dtype=float32), array([0.        , 1.        , 0.99796355, 0.04755384, 0.26782447,
#        0.22693023, 0.9778952 ], dtype=float32), array([0.        , 1.        , 0.994618  , 0.6671514 , 0.23405236,
#        0.7800756 , 0.77352923], dtype=float32), array([0.        , 1.        , 0.9930254 , 0.53486   , 0.21160045,
#        0.6736076 , 0.8053076 ], dtype=float32), array([0.        , 1.        , 0.95552564, 0.7919707 , 0.25477794,
#        0.92286843, 0.68624234], dtype=float32), array([0.        , 1.        , 0.7624064 , 0.7423211 , 0.24523106,
#        0.80696636, 0.59257627], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9981188 , 0.30946058, 0.2336989 ,
#        0.44821936, 0.8838689 ], dtype=float32), array([0.        , 1.        , 0.99793124, 0.04787201, 0.2664693 ,
#        0.22701132, 0.9776258 ], dtype=float32), array([0.        , 1.        , 0.99591345, 0.5285263 , 0.21476328,
#        0.67304456, 0.802786  ], dtype=float32), array([0.        , 1.        , 0.99443924, 0.6670701 , 0.23396999,
#        0.7806638 , 0.7740969 ], dtype=float32), array([0.       , 1.       , 0.9601733, 0.7954798, 0.2557028, 0.922557 ,
#        0.684324 ], dtype=float32), array([0.        , 1.        , 0.7282927 , 0.7408454 , 0.24622893,
#        0.8057143 , 0.5956586 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99826765, 0.3092705 , 0.23613834,
#        0.4468156 , 0.87908316], dtype=float32), array([0.        , 1.        , 0.9979494 , 0.51747245, 0.2122198 ,
#        0.6724407 , 0.8107666 ], dtype=float32), array([0.        , 1.        , 0.9976943 , 0.04773746, 0.26458216,
#        0.22685261, 0.9779707 ], dtype=float32), array([0.        , 1.        , 0.9945643 , 0.6673428 , 0.23281708,
#        0.7821219 , 0.7742286 ], dtype=float32), array([0.        , 1.        , 0.9604786 , 0.79620916, 0.2561338 ,
#        0.92247945, 0.6831318 ], dtype=float32), array([0.        , 1.        , 0.774536  , 0.7440336 , 0.23718439,
#        0.803151  , 0.57833475], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9984806 , 0.30907542, 0.23721346,
#        0.4473846 , 0.8768958 ], dtype=float32), array([0.        , 1.        , 0.9981439 , 0.50776505, 0.20958588,
#        0.6697533 , 0.81325924], dtype=float32), array([0.        , 1.        , 0.9976804 , 0.04707005, 0.2612656 ,
#        0.22674602, 0.97955585], dtype=float32), array([0.        , 1.        , 0.9942984 , 0.6668787 , 0.23402566,
#        0.7809473 , 0.77177805], dtype=float32), array([0.        , 1.        , 0.96793693, 0.7994632 , 0.2567686 ,
#        0.92171246, 0.68068755], dtype=float32), array([0.        , 1.        , 0.85442024, 0.74294716, 0.2358098 ,
#        0.8065792 , 0.59654784], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.99863607, 0.3076298 , 0.2388517 ,
#        0.44753918, 0.87545085], dtype=float32), array([0.        , 1.        , 0.9981773 , 0.50739014, 0.21517015,
#        0.6678932 , 0.81774056], dtype=float32), array([0.        , 1.        , 0.99794   , 0.04704332, 0.25953177,
#        0.22724429, 0.9784    ], dtype=float32), array([0.        , 1.        , 0.99391717, 0.6659988 , 0.2368434 ,
#        0.78154576, 0.7717801 ], dtype=float32), array([0.       , 1.       , 0.9628902, 0.7972098, 0.2567494, 0.9217194,
#        0.6818023], dtype=float32), array([0.        , 1.        , 0.7665804 , 0.7401763 , 0.24276751,
#        0.8068508 , 0.5991838 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.998725  , 0.30757272, 0.23929068,
#        0.44634628, 0.8756393 ], dtype=float32), array([0.        , 1.        , 0.9979692 , 0.5041685 , 0.21691868,
#        0.6676321 , 0.81885076], dtype=float32), array([0.        , 1.        , 0.997764  , 0.04734676, 0.2603431 ,
#        0.22733828, 0.9797168 ], dtype=float32), array([0.        , 1.        , 0.993806  , 0.6657211 , 0.23686627,
#        0.78154427, 0.77106   ], dtype=float32), array([0.        , 1.        , 0.9619758 , 0.7982825 , 0.25682303,
#        0.92167616, 0.6817827 ], dtype=float32), array([0.        , 1.        , 0.8966803 , 0.7413422 , 0.2375355 ,
#        0.80725586, 0.5961381 ], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: [array([0.        , 1.        , 0.9987748 , 0.30757865, 0.24020311,
#        0.44676808, 0.8734422 ], dtype=float32), array([0.        , 1.        , 0.9981072 , 0.04829807, 0.26039767,
#        0.22914547, 0.98269093], dtype=float32), array([0.        , 1.        , 0.9980605 , 0.50105995, 0.21421918,
#        0.6659418 , 0.82058656], dtype=float32), array([0.        , 1.        , 0.9945153 , 0.6647899 , 0.23724368,
#        0.78011644, 0.76981735], dtype=float32), array([0.        , 1.        , 0.9637676 , 0.79922706, 0.25614437,
#        0.9220852 , 0.6825533 ], dtype=float32), array([0.        , 1.        , 0.8063745 , 0.73994625, 0.24376558,
#        0.807312  , 0.59999436], dtype=float32)]
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# coords: []
# Total People in frame = 0
# Number of people in queue: = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/cpu/
# results/manufacturing/cpu/stats.txt
# results/manufacturing/cpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:58: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing CPU', ['results/manufacturing/cpu/output_video.mp4'])
# Out:
# <h5>Manufacturing CPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/cpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.2: Submit to an Edge Compute Node with CPU and IGPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel® Core i5-6500TE</a>. The inference workload should run on the **Intel® HD Graphics 530** integrated GPU.

# %%
#Submit job to the queue
gpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-hd-530 -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 GPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/gpu 2" -N store_core

print(gpu_job_id[0])
# Out:
# 8sBUtJr6uNqfuIyPl7sosgXJrEXiiwqJ

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(gpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:8sBUtJr6uNqfuIyPl7sosgXJrEXiiwqJ) are ready.
# Please wait.....................................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 0
# Number of people in queue: = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/gpu/
# results/manufacturing/gpu/stats.txt
# results/manufacturing/gpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:47: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing GPU', ['results/manufacturing/gpu/output_video.mp4'])
# Out:
# <h5>Manufacturing GPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/gpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.3: Submit to an Edge Compute Node with a Neural Compute Stick 2
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core i5-6500te CPU</a>. The inference workload should run on an <a
#     href="https://software.intel.com/en-us/neural-compute-stick">Intel Neural Compute Stick 2</a> installed in this  node.

# %%
#Submit job to the queue
vpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-ncs2 -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 HETERO:MYRIAD,CPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/vpu 2" -N store_core

print(vpu_job_id[0])
# Out:
# NI6MArXuEbNisLZRnpPsDvwBG5KA1YSC

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(vpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:NI6MArXuEbNisLZRnpPsDvwBG5KA1YSC) are ready.
# Please wait............................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 0
# Number of people in queue: = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/vpu/
# results/manufacturing/vpu/stats.txt
# results/manufacturing/vpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:47: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing VPU', ['results/manufacturing/vpu/output_video.mp4'])
# Out:
# <h5>Manufacturing VPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/vpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.4: Submit to an Edge Compute Node with IEI Mustang-F100-A10
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500te CPU</a> . The inference workload will run on the <a href="https://www.ieiworld.com/mustang-f100/en/"> IEI Mustang-F100-A10 </a> FPGA card installed in this node.

# %%
#Submit job to the queue
fpga_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te:iei-mustang-f100-a10 -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 HETERO:FPGA,CPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/fpga 2" -N store_core

print(fpga_job_id[0])
# Out:
# XWDJ5PO5MwHPdzOoSN6I5j7zY1pRBOWZ

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(fpga_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:XWDJ5PO5MwHPdzOoSN6I5j7zY1pRBOWZ) are ready.
# Please wait...........................................................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# INTELFPGAOCLSDKROOT is not set
# Using script's current directory (/opt/altera/aocl-pro-rte/aclrte-linux64)
#
# aoc was not found, but aocl was found. Assuming only RTE is installed.
#
# AOCL_BOARD_PACKAGE_ROOT is set to /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2. Using that.
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/bin to PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/host/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/lib to LD_LIBRARY_PATH
# aocl program: Running program from /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/libexec
# Programming device: a10gx_2ddr : Intel Vision Accelerator Design with Intel Arria 10 FPGA (acla10_1150_sg20)
# Program succeed.
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue: = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue: = {1: 1, 2: 1}
# Total People in frame = 0
# Number of people in queue: = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/fpga/
# results/manufacturing/fpga/stats.txt
# results/manufacturing/fpga/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:47: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing FPGA', ['results/manufacturing/fpga/output_video.mp4'])
# Out:
# <h5>Manufacturing FPGA</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/fpga/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ***Wait!***
#
# Please wait for all the inference jobs and video rendering to complete before proceeding to the next step.
#
# ## Step 2: Assess Performance
#
# Run the cells below to compare the performance across all 4 devices. The following timings for the model are being compared across all 4 devices:
#
# - Model Loading Time
# - Average Inference Time
# - FPS

# %%
import matplotlib.pyplot as plt

device_list=['cpu', 'gpu', 'fpga', 'vpu']
inference_time=[]
fps=[]
model_load_time=[]

for device in device_list:
    with open('results/manufacturing/'+device+'/stats.txt', 'r') as f:
        inference_time.append(float(f.readline().split("\n")[0]))
        fps.append(float(f.readline().split("\n")[0]))
        model_load_time.append(float(f.readline().split("\n")[0]))

# %%
plt.bar(device_list, inference_time)
plt.xlabel("Device Used")
plt.ylabel("Total Inference Time in Seconds")
plt.show()

# %%
plt.bar(device_list, fps)
plt.xlabel("Device Used")
plt.ylabel("Frames per Second")
plt.show()

# %%
plt.bar(device_list, model_load_time)
plt.xlabel("Device Used")
plt.ylabel("Model Loading Time in Seconds")
plt.show()

# %% [markdown]
# # Step 3: Update Proposal Document
#
# Now that you've completed your hardware testing, you should go back to the proposal document and validate or update your originally proposed hardware. Once you've updated your proposal, you can move on to the next scenario.
